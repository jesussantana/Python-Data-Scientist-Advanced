# %%
from xgboost import XGBRegressor  #pip install xgboost
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

import pandas as pd

# %%
data = pd.read_csv("../../Tascas/Data/DelayedFlights.csv")

# %%
df = data.dropna(subset = ["ArrDelay"])
df = df.sample(frac=1).head(1000)

#df["Month"] = df["Month"].apply(str)
#df["DayofMonth"] = df["DayofMonth"].apply(str)
#df["DayOfWeek"] = df["DayOfWeek"].apply(str)

#dummies = pd.get_dummies(data=df[['Month', 'DayofMonth', 'DayOfWeek', 'Origin', 'Dest']])
#X = dummies.add(X, fill_value=0)

X = df[["AirTime", "Distance", "DepDelay"]]
Y = df["ArrDelay"]

# %%
X_train, X_test, y_train, y_test =  train_test_split(X,Y, test_size=.2, random_state = 1) # split BD

# %%
# escalamos los datos
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# ajustamos XgBoost
# Paralecizacion / ratio aprendizaje / profundidad / % columnas por arbol / resultados / filas / num arboles
model = XGBRegressor(n_jobs=-1, learning_rate=5, max_depth=2, colsample_bytree=.6, verbosity=2, subsample=1, n_estimators=500)

model.fit(X_train, y_train)
# Out:
# 1: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:08:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:08:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:08:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:08:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:08:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:08:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:08:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:08:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# ...

# %%
predictions = model.predict(X_test)
print("R cuadrado: ", r2_score(y_test, predictions))

# %%
# 0.94252636  Super potente llega mas lejos que cualquier arbol de regresion
